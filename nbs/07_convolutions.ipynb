# %% [markdown]
# <a href="https://colab.research.google.com/github/yowashi23/miniai/blob/main/nbs/07_convolutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pwd

# %%
# pip install -e '.[dev]'

# %%
#|default_exp conv

# %% [markdown]
# # Convolutions

# %%
#|export
import torch
from torch import nn

from torch.utils.data import default_collate
from typing import Mapping

from miniai.training import *
from miniai.datasets import *

# %%
import pickle,gzip,math,os,time,shutil,torch,matplotlib as mpl, numpy as np
import pandas as pd,matplotlib.pyplot as plt
from pathlib import Path
from torch import tensor

from torch.utils.data import DataLoader
from typing import Mapping

# %%
mpl.rcParams['image.cmap'] = 'gray'

# %%
MNIST_URL='https://github.com/mnielsen/neural-networks-and-deep-learning/blob/master/data/mnist.pkl.gz?raw=true'
path_data = Path('data')
path_data.mkdir(exist_ok=True)
path_gz = path_data/'mnist.pkl.gz'
from urllib.request import urlretrieve
if not path_gz.exists(): urlretrieve(MNIST_URL, path_gz)

# %%
path_data = Path('data')
path_gz = path_data/'mnist.pkl.gz'
with gzip.open(path_gz, 'rb') as f: ((x_train, y_train), (x_valid, y_valid), _) = pickle.load(f, encoding='latin-1')
x_train, y_train, x_valid, y_valid = map(tensor, [x_train, y_train, x_valid, y_valid])

# %% [markdown]
# In the context of an image, a feature is a visually distinctive attribute. For example, the number 7 is characterized by a horizontal edge near the top of the digit, and a top-right to bottom-left diagonal edge underneath that.
#
# It turns out that finding the edges in an image is a very common task in computer vision, and is surprisingly straightforward. To do it, we use a *convolution*. A convolution requires nothing more than multiplication, and addition.

# %% [markdown]
# ### Understanding the Convolution Equations

# %% [markdown]
# To explain the math behind convolutions, fast.ai student Matt Kleinsmith came up with the very clever idea of showing [CNNs from different viewpoints](https://medium.com/impactai/cnns-from-different-viewpoints-fab7f52d159c).
#
# Here's the input:

# %% [markdown]
# <img alt="The image" width="75" src="https://github.com/fastai/course22p2/blob/master/nbs/images/att_00032.png?raw=1">

# %% [markdown]
# Here's our kernel:

# %% [markdown]
# <img alt="The kernel" width="55" src="https://github.com/fastai/course22p2/blob/master/nbs/images/att_00033.png?raw=1">

# %% [markdown]
# Since the filter fits in the image four times, we have four results:

# %% [markdown]
# <img alt="The activations" width="52" src="https://github.com/fastai/course22p2/blob/master/nbs/images/att_00034.png?raw=1">

# %% [markdown]
# <img alt="Applying the kernel" width="366" caption="Applying the kernel" id="apply_kernel" src="https://github.com/fastai/course22p2/blob/master/nbs/images/att_00035.png?raw=1">

# %% [markdown]
# <img alt="The equation" width="436" caption="The equation" id="eq_view" src="https://github.com/fastai/course22p2/blob/master/nbs/images/att_00036.png?raw=1">

# %%
x_imgs = x_train.view(-1,28,28)
xv_imgs = x_valid.view(-1,28,28)

# %%
mpl.rcParams['figure.dpi'] = 30

# %%
im3 = x_imgs[7]
show_image(im3);

# %%
top_edge = tensor([[-1,-1,-1],
                   [ 0, 0, 0],
                   [ 1, 1, 1]]).float()

# %% [markdown]
# We're going to call this our kernel (because that's what fancy computer vision researchers call these).

# %%
show_image(top_edge, noframe=False);

# %% [markdown]
# The filter will take any window of size 3×3 in our images, and if we name the pixel values like this:
#
# $$\begin{matrix} a1 & a2 & a3 \\ a4 & a5 & a6 \\ a7 & a8 & a9 \end{matrix}$$
#
# it will return $-a1-a2-a3+a7+a8+a9$.

# %%
df = pd.DataFrame(im3[:13,:23])
df.style.format(precision=2).set_properties(**{'font-size':'7pt'}).background_gradient('Greys')
# Out:
# <style type="text/css">
# #T_3c5ac_row0_col0, #T_3c5ac_row0_col1, #T_3c5ac_row0_col2, #T_3c5ac_row0_col3, #T_3c5ac_row0_col4, #T_3c5ac_row0_col5, #T_3c5ac_row0_col6, #T_3c5ac_row0_col7, #T_3c5ac_row0_col8, #T_3c5ac_row0_col9, #T_3c5ac_row0_col10, #T_3c5ac_row0_col11, #T_3c5ac_row0_col12, #T_3c5ac_row0_col13, #T_3c5ac_row0_col14, #T_3c5ac_row0_col15, #T_3c5ac_row0_col16, #T_3c5ac_row0_col17, #T_3c5ac_row0_col18, #T_3c5ac_row0_col19, #T_3c5ac_row0_col20, #T_3c5ac_row0_col21, #T_3c5ac_row0_col22, #T_3c5ac_row1_col0, #T_3c5ac_row1_col1, #T_3c5ac_row1_col2, #T_3c5ac_row1_col3, #T_3c5ac_row1_col4, #T_3c5ac_row1_col5, #T_3c5ac_row1_col6, #T_3c5ac_row1_col7, #T_3c5ac_row1_col8, #T_3c5ac_row1_col9, #T_3c5ac_row1_col10, #T_3c5ac_row1_col11, #T_3c5ac_row1_col12, #T_3c5ac_row1_col13, #T_3c5ac_row1_col14, #T_3c5ac_row1_col15, #T_3c5ac_row1_col16, #T_3c5ac_row1_col17, #T_3c5ac_row1_col18, #T_3c5ac_row1_col19, #T_3c5ac_row1_col20, #T_3c5ac_row1_col21, #T_3c5ac_row1_col22, #T_3c5ac_row2_col0, #T_3c5ac_row2_col1, #T_3c5ac_row2_col2, #T_3c5ac_row2_col3, #T_3c5ac_row2_col4, #T_3c5ac_row2_col5, #T_3c5ac_row2_col6, #T_3c5ac_row2_col7, #T_3c5ac_row2_col8, #T_3c5ac_row2_col9, #T_3c5ac_row2_col10, #T_3c5ac_row2_col11, #T_3c5ac_row2_col12, #T_3c5ac_row2_col13, #T_3c5ac_row2_col14, #T_3c5ac_row2_col15, #T_3c5ac_row2_col16, #T_3c5ac_row2_col17, #T_3c5ac_row2_col18, #T_3c5ac_row2_col19, #T_3c5ac_row2_col20, #T_3c5ac_row2_col21, #T_3c5ac_row2_col22, #T_3c5ac_row3_col0, #T_3c5ac_row3_col1, #T_3c5ac_row3_col2, #T_3c5ac_row3_col3, #T_3c5ac_row3_col4, #T_3c5ac_row3_col5, #T_3c5ac_row3_col6, #T_3c5ac_row3_col7, #T_3c5ac_row3_col8, #T_3c5ac_row3_col9, #T_3c5ac_row3_col10, #T_3c5ac_row3_col11, #T_3c5ac_row3_col12, #T_3c5ac_row3_col13, #T_3c5ac_row3_col14, #T_3c5ac_row3_col15, #T_3c5ac_row3_col16, #T_3c5ac_row3_col17, #T_3c5ac_row3_col18, #T_3c5ac_row3_col19, #T_3c5ac_row3_col20, #T_3c5ac_row3_col21, #T_3c5ac_row3_col22, #T_3c5ac_row4_col0, #T_3c5ac_row4_col1, #T_3c5ac_row4_col2, #T_3c5ac_row4_col3, #T_3c5ac_row4_col4, #T_3c5ac_row4_col5, #T_3c5ac_row4_col6, #T_3c5ac_row4_col7, #T_3c5ac_row4_col8, #T_3c5ac_row4_col9, #T_3c5ac_row4_col10, #T_3c5ac_row4_col11, #T_3c5ac_row4_col12, #T_3c5ac_row4_col13, #T_3c5ac_row4_col14, #T_3c5ac_row4_col15, #T_3c5ac_row4_col16, #T_3c5ac_row4_col17, #T_3c5ac_row4_col18, #T_3c5ac_row4_col19, #T_3c5ac_row4_col20, #T_3c5ac_row4_col21, #T_3c5ac_row4_col22, #T_3c5ac_row5_col0, #T_3c5ac_row5_col1, #T_3c5ac_row5_col2, #T_3c5ac_row5_col3, #T_3c5ac_row5_col4, #T_3c5ac_row5_col5, #T_3c5ac_row5_col6, #T_3c5ac_row5_col7, #T_3c5ac_row5_col8, #T_3c5ac_row5_col9, #T_3c5ac_row5_col10, #T_3c5ac_row5_col22, #T_3c5ac_row6_col0, #T_3c5ac_row6_col1, #T_3c5ac_row6_col2, #T_3c5ac_row6_col3, #T_3c5ac_row6_col4, #T_3c5ac_row6_col5, #T_3c5ac_row6_col6, #T_3c5ac_row6_col7, #T_3c5ac_row6_col8, #T_3c5ac_row7_col0, #T_3c5ac_row7_col1, #T_3c5ac_row7_col2, #T_3c5ac_row7_col3, #T_3c5ac_row7_col4, #T_3c5ac_row7_col5, #T_3c5ac_row7_col6, #T_3c5ac_row7_col7, #T_3c5ac_row7_col8, #T_3c5ac_row8_col0, #T_3c5ac_row8_col1, #T_3c5ac_row8_col2, #T_3c5ac_row8_col3, #T_3c5ac_row8_col4, #T_3c5ac_row8_col5, #T_3c5ac_row8_col6, #T_3c5ac_row8_col7, #T_3c5ac_row8_col8, #T_3c5ac_row9_col0, #T_3c5ac_row9_col1, #T_3c5ac_row9_col2, #T_3c5ac_row9_col3, #T_3c5ac_row9_col4, #T_3c5ac_row9_col5, #T_3c5ac_row9_col6, #T_3c5ac_row9_col7, #T_3c5ac_row9_col8, #T_3c5ac_row9_col13, #T_3c5ac_row9_col14, #T_3c5ac_row9_col15, #T_3c5ac_row9_col16, #T_3c5ac_row10_col0, #T_3c5ac_row10_col1, #T_3c5ac_row10_col2, #T_3c5ac_row10_col3, #T_3c5ac_row10_col4, #T_3c5ac_row10_col5, #T_3c5ac_row10_col6, #T_3c5ac_row10_col7, #T_3c5ac_row10_col8, #T_3c5ac_row10_col9, #T_3c5ac_row10_col10, #T_3c5ac_row10_col11, #T_3c5ac_row10_col12, #T_3c5ac_row10_col13, #T_3c5ac_row10_col14, #T_3c5ac_row10_col15, #T_3c5ac_row10_col16, #T_3c5ac_row10_col22, #T_3c5ac_row11_col0, #T_3c5ac_row11_col1, #T_3c5ac_row11_col2, #T_3c5ac_row11_col3, #T_3c5ac_row11_col4, #T_3c5ac_row11_col5, #T_3c5ac_row11_col6, #T_3c5ac_row11_col7, #T_3c5ac_row11_col8, #T_3c5ac_row11 ...
#   font-size: 7pt;
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_3c5ac_row5_col11 {
#   font-size: 7pt;
#   background-color: #ececec;
#   color: #000000;
# }
# #T_3c5ac_row5_col12 {
#   font-size: 7pt;
#   background-color: #e8e8e8;
#   color: #000000;
# }
# #T_3c5ac_row5_col13 {
#   font-size: 7pt;
#   background-color: #b0b0b0;
#   color: #000000;
# }
# #T_3c5ac_row5_col14, #T_3c5ac_row5_col15, #T_3c5ac_row5_col16, #T_3c5ac_row5_col17, #T_3c5ac_row5_col18, #T_3c5ac_row5_col19, #T_3c5ac_row6_col13, #T_3c5ac_row6_col20, #T_3c5ac_row7_col9, #T_3c5ac_row7_col10, #T_3c5ac_row7_col11, #T_3c5ac_row7_col12, #T_3c5ac_row7_col13, #T_3c5ac_row7_col20, #T_3c5ac_row7_col21, #T_3c5ac_row7_col22, #T_3c5ac_row8_col10, #T_3c5ac_row8_col11, #T_3c5ac_row8_col20, #T_3c5ac_row8_col21, #T_3c5ac_row8_col22, #T_3c5ac_row9_col20, #T_3c5ac_row10_col20, #T_3c5ac_row11_col20 {
#   font-size: 7pt;
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_3c5ac_row5_col20 {
#   font-size: 7pt;
#   background-color: #626262;
#   color: #f1f1f1;
# }
# #T_3c5ac_row5_col21 {
#   font-size: 7pt;
#   background-color: #fcfcfc;
#   color: #000000;
# }
# #T_3c5ac_row6_col9 {
#   font-size: 7pt;
#   background-color: #dbdbdb;
#   color: #000000;
# }
# #T_3c5ac_row6_col10 {
#   font-size: 7pt;
#   background-color: #878787;
#   color: #f1f1f1;
# }
# #T_3c5ac_row6_col11 {
#   font-size: 7pt;
#   background-color: #212121;
#   color: #f1f1f1;
# }
# #T_3c5ac_row6_col12 {
#   font-size: 7pt;
#   background-color: #1e1e1e;
#   color: #f1f1f1;
# }
# #T_3c5ac_row6_col14, #T_3c5ac_row7_col14 {
#   font-size: 7pt;
#   background-color: #020202;
#   color: #f1f1f1;
# }
# #T_3c5ac_row6_col15, #T_3c5ac_row6_col16, #T_3c5ac_row6_col17, #T_3c5ac_row6_col18, #T_3c5ac_row6_col19, #T_3c5ac_row7_col15, #T_3c5ac_row7_col16, #T_3c5ac_row7_col17, #T_3c5ac_row7_col18, #T_3c5ac_row7_col19, #T_3c5ac_row8_col18, #T_3c5ac_row8_col19, #T_3c5ac_row9_col19, #T_3c5ac_row10_col19, #T_3c5ac_row11_col18, #T_3c5ac_row11_col19, #T_3c5ac_row12_col17, #T_3c5ac_row12_col18, #T_3c5ac_row12_col19 {
#   font-size: 7pt;
#   background-color: #010101;
#   color: #f1f1f1;
# }
# #T_3c5ac_row6_col21 {
#   font-size: 7pt;
#   background-color: #727272;
#   color: #f1f1f1;
# }
# #T_3c5ac_row6_col22 {
#   font-size: 7pt;
#   background-color: #dcdcdc;
#   color: #000000;
# }
# #T_3c5ac_row8_col9 {
#   font-size: 7pt;
#   background-color: #777777;
#   color: #f1f1f1;
# }
# #T_3c5ac_row8_col12 {
#   font-size: 7pt;
#   background-color: #1a1a1a;
#   color: #f1f1f1;
# }
# #T_3c5ac_row8_col13 {
#   font-size: 7pt;
#   background-color: #8f8f8f;
#   color: #f1f1f1;
# }
# #T_3c5ac_row8_col14, #T_3c5ac_row8_col15, #T_3c5ac_row8_col16 {
#   font-size: 7pt;
#   background-color: #909090;
#   color: #f1f1f1;
# }
# #T_3c5ac_row8_col17, #T_3c5ac_row11_col17 {
#   font-size: 7pt;
#   background-color: #525252;
#   color: #f1f1f1;
# }
# #T_3c5ac_row9_col9 {
#   font-size: 7pt;
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_3c5ac_row9_col10, #T_3c5ac_row9_col11, #T_3c5ac_row9_col22 {
#   font-size: 7pt;
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_3c5ac_row9_col12 {
#   font-size: 7pt;
#   background-color: #f4f4f4;
#   color: #000000;
# }
# #T_3c5ac_row9_col17, #T_3c5ac_row11_col21 {
#   font-size: 7pt;
#   background-color: #f8f8f8;
#   color: #000000;
# }
# #T_3c5ac_row9_col18 {
#   font-size: 7pt;
#   background-color: #1f1f1f;
#   color: #f1f1f1;
# }
# #T_3c5ac_row9_col21 {
#   font-size: 7pt;
#   background-color: #646464;
#   color: #f1f1f1;
# }
# #T_3c5ac_row10_col17 {
#   font-size: 7pt;
#   background-color: #c5c5c5;
#   color: #000000;
# }
# #T_3c5ac_row10_col18 {
#   font-size: 7pt;
#   background-color: #0c0c0c;
#   color: #f1f1f1;
# }
# #T_3c5ac

# %%
(im3[3:6,14:17] * top_edge).sum()
# Out:
# tensor(2.9727)

# %%
(im3[7:10,14:17] * top_edge).sum()
# Out:
# tensor(-2.9570)

# %%
def apply_kernel(row, col, kernel): return (im3[row-1:row+2,col-1:col+2] * kernel).sum()

# %%
apply_kernel(4,15,top_edge)
# Out:
# tensor(2.9727)

# %% [markdown]
# <img src="https://github.com/fastai/course22p2/blob/master/nbs/images/chapter9_nopadconv.svg?raw=1" id="nopad_conv" caption="Applying a kernel across a grid" alt="Applying a kernel across a grid" width="400">

# %%
[[(i,j) for j in range(5)] for i in range(5)]
# Out:
# [[(0, 0), (0, 1), (0, 2), (0, 3), (0, 4)],
#  [(1, 0), (1, 1), (1, 2), (1, 3), (1, 4)],
#  [(2, 0), (2, 1), (2, 2), (2, 3), (2, 4)],
#  [(3, 0), (3, 1), (3, 2), (3, 3), (3, 4)],
#  [(4, 0), (4, 1), (4, 2), (4, 3), (4, 4)]]

# %%
rng = range(1,27)
print(len(rng))
top_edge3 = tensor([[apply_kernel(i,j,top_edge) for j in rng] for i in rng])
show_image(top_edge3);
# Out:
# 26

# %%
left_edge = tensor([[-1,0,1],
                    [-1,0,1],
                    [-1,0,1]]).float()

# %%
show_image(left_edge, noframe=False);

# %%
left_edge3 = tensor([[apply_kernel(i,j,left_edge) for j in rng] for i in rng])
show_image(left_edge3);

# %% [markdown]
# <img alt="Result of applying a 3×3 kernel to a 4×4 image" width="782" caption="Result of applying a 3×3 kernel to a 4×4 image (courtesy of Vincent Dumoulin and Francesco Visin)" id="three_ex_four_conv" src="https://github.com/fastai/course22p2/blob/master/nbs/images/att_00028.png?raw=1">

# %% [markdown]
# ### Convolutions in PyTorch

# %%
import torch.nn.functional as F
import torch

# %% [markdown]
# What to do if you have [2 months to complete your thesis](https://github.com/Yangqing/caffe/wiki/Convolution-in-Caffe:-a-memo)? Use [im2col](https://hal.inria.fr/inria-00112631/).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here's a sample [numpy implementation](https://github.com/3outeille/CNNumpy/blob/5394f13e7ed67a808a3e39fd381f168825d65ff5/src/fast/utils.py#L360).

# %%
inp = im3[None,None,:,:].float()
inp_unf = F.unfold(inp, (3,3))[0]
inp_unf.shape
# Out:
# torch.Size([9, 676])

# %%
w = left_edge.view(-1)
w.shape
# Out:
# torch.Size([9])

# %%
out_unf = w@inp_unf
out_unf.shape
# Out:
# torch.Size([676])

# %%
out = out_unf.view(26,26)
show_image(out);

# %%
# %timeit -n 1 tensor([[apply_kernel(i,j,left_edge) for j in rng] for i in rng]);
# Out:
# 10.3 ms ± 1.55 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit -n 100 (w@F.unfold(inp, (3,3))[0]).view(26,26);
# Out:
# 49.2 µs ± 16 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit -n 100 F.conv2d(inp, left_edge[None,None])
# Out:
# The slowest run took 9.54 times longer than the fastest. This could mean that an intermediate result is being cached.
# 32.7 µs ± 43.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
diag1_edge = tensor([[ 0,-1, 1],
                     [-1, 1, 0],
                     [ 1, 0, 0]]).float()

# %%
show_image(diag1_edge, noframe=False);

# %%
diag2_edge = tensor([[ 1,-1, 0],
                     [ 0, 1,-1],
                     [ 0, 0, 1]]).float()

# %%
show_image(diag2_edge, noframe=False);

# %%
xb = x_imgs[:16][:,None]
xb.shape
# Out:
# torch.Size([16, 1, 28, 28])

# %%
edge_kernels = torch.stack([left_edge, top_edge, diag1_edge, diag2_edge])[:,None]
edge_kernels.shape
# Out:
# torch.Size([4, 1, 3, 3])

# %%
batch_features = F.conv2d(xb, edge_kernels)
batch_features.shape
# Out:
# torch.Size([16, 4, 26, 26])

# %% [markdown]
# The output shape shows we gave 64 images in the mini-batch, 4 kernels, and 26×26 edge maps (we started with 28×28 images, but lost one pixel from each side as discussed earlier). We can see we get the same results as when we did this manually:

# %%
xb.shape
# Out:
# torch.Size([16, 1, 28, 28])

# %%
img0 = xb[1,0]
show_image(img0);

# %%
show_images([batch_features[1,i] for i in range(4)])

# %% [markdown]
# ### Strides and Padding

# %% [markdown]
# With appropriate padding, we can ensure that the output activation map is the same size as the original image.

# %% [markdown]
# <img src="https://github.com/fastai/course22p2/blob/master/nbs/images/chapter9_padconv.svg?raw=1" id="pad_conv" caption="A convolution with padding" alt="A convolution with padding" width="600">

# %% [markdown]
# With a 5×5 input, 4×4 kernel, and 2 pixels of padding, we end up with a 6×6 activation map.

# %% [markdown]
# <img alt="A 4×4 kernel with 5×5 input and 2 pixels of padding" width="783" caption="A 4×4 kernel with 5×5 input and 2 pixels of padding (courtesy of Vincent Dumoulin and Francesco Visin)" id="four_by_five_conv" src="https://github.com/fastai/course22p2/blob/master/nbs/images/att_00029.png?raw=1">

# %% [markdown]
# If we add a kernel of size `ks` by `ks` (with `ks` an odd number), the necessary padding on each side to keep the same shape is `ks//2`.
#
# We could move over two pixels after each kernel application. This is known as a *stride-2* convolution.

# %% [markdown]
# <img alt="A 3×3 kernel with 5×5 input, stride-2 convolution, and 1 pixel of padding" width="774" caption="A 3×3 kernel with 5×5 input, stride-2 convolution, and 1 pixel of padding (courtesy of Vincent Dumoulin and Francesco Visin)" id="three_by_five_conv" src="https://github.com/fastai/course22p2/blob/master/nbs/images/att_00030.png?raw=1">

# %% [markdown]
# ## Creating the CNN

# %%
n,m = x_train.shape
c = y_train.max()+1
nh = 50

# %%
n, m, c, nh
# Out:
# (50000, 784, tensor(10), 50)

# %%
model = nn.Sequential(nn.Linear(m,nh), nn.ReLU(), nn.Linear(nh,10))

# %%
broken_cnn = nn.Sequential(
    nn.Conv2d(1,30, kernel_size=3, padding=1),
    nn.ReLU(),
    nn.Conv2d(30,10, kernel_size=3, padding=1)
)

# %%
xb.shape
# Out:
# torch.Size([16, 1, 28, 28])

# %%
broken_cnn[:2](xb).shape
# Out:
# torch.Size([16, 30, 28, 28])

# %%
broken_cnn(xb).shape
# Out:
# torch.Size([16, 10, 28, 28])

# %%
list(broken_cnn.parameters())[2].shape
# Out:
# torch.Size([10, 30, 3, 3])

# %%
list(broken_cnn.parameters())[3].shape
# Out:
# torch.Size([10])

# %%
#|export
def conv(ni, nf, ks=3, stride=2, act=True):
    res = nn.Conv2d(ni, nf, stride=stride, kernel_size=ks, padding=ks//2)
    if act: res = nn.Sequential(res, nn.ReLU())
    return res

# %% [markdown]
# Refactoring parts of your neural networks like this makes it much less likely you'll get errors due to inconsistencies in your architectures, and makes it more obvious to the reader which parts of your layers are actually changing.

# %%
simple_cnn = nn.Sequential(
    conv(1 ,4),            #14x14
    conv(4 ,8),            #7x7
    conv(8 ,16),           #4x4
    conv(16,16),           #2x2
    conv(16,10, act=False), #1x1
    nn.Flatten(),
)

# %%
simple_cnn(xb).shape
# Out:
# torch.Size([16, 10])

# %%
??Dataset

# %%
x_imgs = x_train.view(-1,1,28,28)
xv_imgs = x_valid.view(-1,1,28,28)
train_ds,valid_ds = Dataset(x_imgs, y_train),Dataset(xv_imgs, y_valid)

# %%
x_train.shape, x_imgs.shape, x_valid.shape, xv_imgs.shape
# Out:
# (torch.Size([50000, 784]),
#  torch.Size([50000, 1, 28, 28]),
#  torch.Size([10000, 784]),
#  torch.Size([10000, 1, 28, 28]))

# %%
y_train.shape, y_valid.shape
# Out:
# (torch.Size([50000]), torch.Size([10000]))

# %%
#|export
def_device = 'mps' if torch.backends.mps.is_available() else 'cuda' if torch.cuda.is_available() else 'cpu'

def to_device(x, device=def_device):
    if isinstance(x, torch.Tensor): return x.to(device)
    if isinstance(x, Mapping): return {k:v.to(device) for k,v in x.items()}
    return type(x)(to_device(o, device) for o in x)

def collate_device(b): return to_device(default_collate(b))

# %%
??get_dls

# %%
??DataLoader

# %%
from torch import optim

bs = 256
lr = 0.4
train_dl,valid_dl = get_dls(train_ds, valid_ds, bs, collate_fn=collate_device)
opt = optim.SGD(simple_cnn.parameters(), lr=lr)

# %%
loss,acc = fit(5, simple_cnn.to(def_device), F.cross_entropy, opt, train_dl, valid_dl)
# Out:
# 0 0.6180139537811279 0.7945999994277954
# 1 0.1676539389848709 0.9481000004768372
# 2 0.13678860914707183 0.9573000002861023
# 3 0.10951401934623718 0.9684999992370605
# 4 0.1281936767101288 0.9618999992370606

# %%
def_device
# Out:
# 'cpu'

# %%
opt = optim.SGD(simple_cnn.parameters(), lr=lr/4)
loss,acc = fit(5, simple_cnn.to(def_device), F.cross_entropy, opt, train_dl, valid_dl)
# Out:
# 0 0.08986593015193939 0.9721999992370606
# 1 0.08907295107841491 0.973099999332428
# 2 0.0844394376039505 0.9742999992370606
# 3 0.08635845127105712 0.973600000667572
# 4 0.08326918449401856 0.9749999992370606

# %% [markdown]
# ### Understanding Convolution Arithmetic

# %% [markdown]
# In an input of size `64x1x28x28` the axes are `batch,channel,height,width`. This is often represented as `NCHW` (where `N` refers to batch size). Tensorflow, on the other hand, uses `NHWC` axis order (aka "channels-last"). Channels-last is faster for many models, so recently it's become more common to see this as an option in PyTorch too.
#
# We have 1 input channel, 4 output channels, and a 3×3 kernel.

# %%
simple_cnn[0][0]
# Out:
# Conv2d(1, 4, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))

# %%
conv1 = simple_cnn[0][0]
conv1.weight.shape
# Out:
# torch.Size([4, 1, 3, 3])

# %%
conv1.bias.shape
# Out:
# torch.Size([4])

# %% [markdown]
# The *receptive field* is the area of an image that is involved in the calculation of a layer. *conv-example.xlsx* shows the calculation of two stride-2 convolutional layers using an MNIST digit. Here's what we see if we click on one of the cells in the *conv2* section, which shows the output of the second convolutional layer, and click *trace precedents*.

# %% [markdown]
# <img alt="Immediate precedents of conv2 layer" width="308" caption="Immediate precedents of Conv2 layer" id="preced1" src="https://github.com/fastai/course22p2/blob/master/nbs/images/att_00068.png?raw=1">

# %% [markdown]
# The blue highlighted cells are its *precedents*—that is, the cells used to calculate its value. These cells are the corresponding 3×3 area of cells from the input layer (on the left), and the cells from the filter (on the right). Click *trace precedents* again:

# %% [markdown]
# <img alt="Secondary precedents of conv2 layer" width="601" caption="Secondary precedents of Conv2 layer" id="preced2" src="https://github.com/fastai/course22p2/blob/master/nbs/images/att_00069.png?raw=1">

# %% [markdown]
# In this example, we have just two convolutional layers. We can see that a 7×7 area of cells in the input layer is used to calculate the single green cell in the Conv2 layer. This is the *receptive field*
#
# The deeper we are in the network (specifically, the more stride-2 convs we have before a layer), the larger the receptive field for an activation in that layer.

# %% [markdown]
# ## Color Images

# %% [markdown]
# A colour picture is a rank-3 tensor:

# %%
from torchvision.io import read_image

# %%
im = read_image('images/grizzly.jpg')
im.shape
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_4177/3161624202.py in <cell line: 0>()
# ----> 1 im = read_image('images/grizzly.jpg')
#       2 im.shape
#
# /usr/local/lib/python3.12/dist-packages/torchvision/io/image.py in read_image(path, mode, apply_exif_orientation)
#     334     if not torch.jit.is_scripting() and not torch.jit.is_tracing():
#     335         _log_api_usage_once(read_image)
# --> 336     data = read_file(path)
#     337     return decode_image(data, mode, apply_exif_orientation=apply_exif_orientation)
#     338
#
# /usr/local/lib/python3.12/dist-packages/torchvision/io/image.py in read_file(path)
#      62     if not torch.jit.is_scripting() and not torch.jit.is_tracing():
#      63         _log_api_usage_once(read_file)
# ---> 64     data = torch.ops.image.read_file(str(path))
#      65     return data
#      66
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in __call__(self, *args, **kwargs)
#    1207             # pyrefly: ignore [bad-argument-type]
#    1208             return _call_overload_packet_from_python(self, *args, **kwargs)
# -> 1209         return self._op(*args, **kwargs)
#    1210
#    1211     # TODO: use this to make a __dir__
#
# RuntimeError: [Errno 2] No such file or directory: 'images/grizzly.jpg'

# %%
show_image(im.permute(1,2,0));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4177/3828061952.py in <cell line: 0>()
# ----> 1 show_image(im.permute(1,2,0));
#
# NameError: name 'im' is not defined

# %%
_,axs = plt.subplots(1,3)
for bear,ax,color in zip(im,axs,('Reds','Greens','Blues')): show_image(255-bear, ax=ax, cmap=color)

# %% [markdown]
# <img src="https://github.com/fastai/course22p2/blob/master/nbs/images/chapter9_rgbconv.svg?raw=1" id="rgbconv" caption="Convolution over an RGB image" alt="Convolution over an RGB image" width="550">

# %% [markdown]
# These are then all added together, to produce a single number, for each grid location, for each output feature.

# %% [markdown]
# <img src="https://github.com/fastai/course22p2/blob/master/nbs/images/chapter9_rgb_conv_stack.svg?raw=1" id="rgbconv2" caption="Adding the RGB filters" alt="Adding the RGB filters" width="500">

# %% [markdown]
# We have `ch_out` filters like this, so in the end, the result of our convolutional layer will be a batch of images with `ch_out` channels.

# %% [markdown]
# ## Export -

# %%
import nbdev; nbdev.nbdev_export()
