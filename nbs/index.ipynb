# %%
#| hide
from miniai.core import *

# %% [markdown]
# # miniai
#
# > personal repo for miniai

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install miniai in Development mode

# %% [markdown]
# ```sh
# # make sure miniai package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to miniai
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/yowashi23/miniai.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c yowashi23 miniai
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install miniai
# ```
#
#
# [repo]: https://github.com/yowashi23/miniai
# [docs]: https://yowashi23.github.io/miniai/
# [pypi]: https://pypi.org/project/miniai/
# [conda]: https://anaconda.org/yowashi23/miniai

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/yowashi23/miniai
# [docs]: https://yowashi23.github.io/miniai/
# [pypi]: https://pypi.org/project/miniai/
# [conda]: https://anaconda.org/yowashi23/miniai

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
